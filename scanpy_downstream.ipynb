# %%
import scanpy as sc
import anndata as ad

# %%
sc.set_figure_params(dpi=80, color_map='viridis')
sc.settings.verbosity = 4
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.7
# scanpy      1.10.1
# -----
# PIL                 10.3.0
# appnope             0.1.4
# asttokens           NA
# cffi                1.16.0
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.6.7
# decorator           5.1.1
# executing           2.0.1
# h5py                3.11.0
# igraph              0.11.4
# ipykernel           6.29.3
# jedi                0.19.1
# joblib              1.4.0
# kiwisolver          1.4.5
# legacy_api_wrap     NA
# leidenalg           0.10.2
# llvmlite            0.42.0
# matplotlib          3.8.4
# matplotlib_inline   0.1.7
# mpl_toolkits        NA
# natsort             8.4.0
# numba               0.59.1
# numpy               1.26.4
# packaging           23.1
# pandas              2.2.2
# parso               0.8.4
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.10.0
# prompt_toolkit      3.0.42
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pyparsing           3.1.2
# pytz                2024.1
# ruamel              NA
# scipy               1.13.0
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.2
# stack_data          0.6.2
# texttable           1.7.0
# threadpoolctl       3.4.0
# tornado             6.4
# traitlets           5.14.2
# vscode              NA
# wcwidth             0.2.13
# zmq                 25.1.1
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# -----
# Python 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:54:21) [Clang 16.0.6 ]
# macOS-14.1-arm64-arm-64bit
# -----
# Session information updated at 2024-04-18 17:17

# %%
ad_scrna_path = "/Users/amulyagarimella/Downloads/compproj/AD_scRNA/RNA_processed.h5ad"
ad_adata = sc.read_h5ad(ad_scrna_path)

# %%
sc.pl.umap(
    ad_adata,
    color=["leiden_res_0.02", "leiden_res_0.50", "leiden_res_2.00"],
    legend_loc="on data",
)

# %%
sc.tl.rank_genes_groups(ad_adata, groupby="major.celltype")
# Out:
# ranking genes
#     consider 'major.celltype' groups:
#     with sizes: [ 27276 173246  61056  12812 119456  19272   1846]
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:10:11)

# %%
ad_adata.write("/Users/amulyagarimella/Downloads/compproj/AD_scRNA/RNA_processed_degs.h5ad")
